# %%
from PyEMD import EMD
import pylab as plt


from pyhht.visualization import plot_imfs
import numpy as np
import math
#from pyhht.emd import EMD
import matplotlib.pyplot as plt
from tftb.generators import fmconst
from scipy import angle, unwrap
from scipy.signal import hilbert
import pandas as pd
from scipy import signal
import statistics


from scipy.stats import entropy
from math import log, e
import timeit


df=pd.read_excel("C:/Users/Dell/Documents/sem8/Data Set/MCF7_100_S.xlsx")
a1=df["t"]
list(a1)
import numpy as np
a1ar=np.asarray(a1)
type(a1ar)
#print(a1ar)
a2=df["modes"]
list(a2)
import numpy as np
a2ar=np.asarray(a2)
type(a2ar)
#print(a2ar)
x=a1ar+a2ar
plt.plot(a1ar,a2ar);



# Define signal

# Execute EMD on signal
IMF = EMD().emd(a2ar,a1ar)
N = IMF.shape[0]+1
# Plot results
plt.figure(figsize=(18,12))
plt.subplot(N,1,1)
plt.plot(a1ar, a2ar, 'r')
plt.title("Input signal:")
plt.xlabel("Time [s]")
for n, imf in enumerate(IMF):
    plt.figure(figsize=(18,12))
    plt.subplot(N,1,n+2)
    plt.plot(a1ar, imf, 'g')
    plt.title("IMF "+str(n+1))
    plt.xlabel("Time [s]")
plt.tight_layout()
#plt.savefig('simple_example')
plt.show()

plt.ylabel("Instataneous frequency:")
plt.xlabel("Time [hr]")
plt.ylim(0, 1000.0)

hs1 = hilbert(IMF[0])
omega_imf_one = unwrap(angle(hs1))/(2*3.14)
f_inst_imf_one = np.diff(omega_imf_one) 
plt.plot(a1ar[1:658],abs(f_inst_imf_one[1:658])/0.001,'-r',label='imf0')

hs2 = hilbert(IMF[1])
omega_imf_2 = unwrap(angle(hs2))/(2*3.14)
f_inst_imf_2 = np.diff(omega_imf_2) 
plt.plot(a1ar[1:658],abs(f_inst_imf_2[1:658])/0.001,'-b',label='imf1')

hs3 = hilbert(IMF[2])
omega_imf_3 = unwrap(angle(hs3))/(2*3.14)
f_inst_imf_3 = np.diff(omega_imf_3) 
plt.plot(a1ar[1:658],abs(f_inst_imf_3[1:658])/0.001,'-g',label='imf2')

hs4 = hilbert(IMF[3])
omega_imf_4 = unwrap(angle(hs4))/(2*3.14)
f_inst_imf_4 = np.diff(omega_imf_4) 
plt.plot(a1ar[1:658],abs(f_inst_imf_4[1:658])/0.001,'-y',label='imf3')
#plt.show()

hs5 = hilbert(IMF[4])
omega_imf_5 = unwrap(angle(hs5))/(2*3.14)
f_inst_imf_5 = np.diff(omega_imf_one) 
plt.plot(a1ar[1:658],abs(f_inst_imf_5[1:658])/0.001,'-r',label='imf4')

hs6 = hilbert(IMF[5])
omega_imf_6 = unwrap(angle(hs6))/(2*3.14)
f_inst_imf_6 = np.diff(omega_imf_6) 
plt.plot(a1ar[1:658],abs(f_inst_imf_6[1:658])/0.001,'-g',label='imf5')

hs7 = hilbert(IMF[6])
omega_imf_7 = unwrap(angle(hs7))/(2*3.14)
f_inst_imf_7 = np.diff(omega_imf_7) 
plt.plot(a1ar[1:658],abs(f_inst_imf_7[1:658])/0.001,'-b',label='imf6')

hs8 = hilbert(IMF[7])
omega_imf_8 = unwrap(angle(hs8))/(2*3.14)
f_inst_imf_8 = np.diff(omega_imf_8) 
plt.plot(a1ar[1:658],abs(f_inst_imf_8[1:658])/0.001,'-y',label='imf7')
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF_100_s_freqvstime.png",dpi=300)

# %%
import numpy as np
rate = 30.0
t = a1ar
x0 = IMF[0]
x1 = IMF[1]
x2 = IMF[2]
x3 = IMF[3]
x4 = IMF[4]
x5 = IMF[5]
x6 = IMF[6]
x7 = IMF[7]


p0 = 20*np.log10(np.abs(np.fft.rfft(x0)))
f0 = np.linspace(0, rate/2, len(p0))
plt.plot(f0, abs(p0))
p1 = 20*np.log10(np.abs(np.fft.rfft(x1)))
f1 = np.linspace(0, rate/2, len(p1))
plt.plot(f1, abs(p1))
p2 = 20*np.log10(np.abs(np.fft.rfft(x2)))
f2 = np.linspace(0, rate/2, len(p2))
plt.plot(f2, abs(p2))
p3 = 20*np.log10(np.abs(np.fft.rfft(x3)))
f3 = np.linspace(0, rate/2, len(p3))
plt.plot(f3, abs(p3))
p4 = 20*np.log10(np.abs(np.fft.rfft(x4)))
f4 = np.linspace(0, rate/2, len(p4))
plt.plot(f4, abs(p4))
p5 = 20*np.log10(np.abs(np.fft.rfft(x5)))
f5 = np.linspace(0, rate/2, len(p5))
plt.plot(f5, abs(p5))
p6 = 20*np.log10(np.abs(np.fft.rfft(x6)))
f6 = np.linspace(0, rate/2, len(p6))
plt.plot(f6, abs(p6))
p7 = 20*np.log10(np.abs(np.fft.rfft(x7)))
f7 = np.linspace(0, rate/2, len(p7))
plt.plot(f7, abs(p7))

# %%
import numpy as np
print('\nmean are as follows')
print(np.mean(abs(p0)))
print(np.mean(abs(p1)))
print(np.mean(abs(p2)))
print(np.mean(abs(p3)))
print(np.mean(abs(p4)))
print(np.mean(abs(p5)))
print(np.mean(abs(p6)))
print(np.mean(abs(p7)))
print('\nstandard deviation are as follows')
print(np.std(p0))
print(np.std(p1))
print(np.std(p2))
print(np.std(p3))
print(np.std(p4))
print(np.std(p5))
print(np.std(p6))
print(np.std(p7))
print('\nVariance are as follows')
print(statistics.variance(p0))
print(statistics.variance(p1))
print(statistics.variance(p2))
print(statistics.variance(p3))
print(statistics.variance(p4))
print(statistics.variance(p5))
print(statistics.variance(p6))
print(statistics.variance(p7))
pxx_den = np.repeat(p0,2)
# Out:
# mean are as follows
# 6.026322647153613
# 12.127585343971868
# 20.317346364476233
# 26.716778226847918
# 18.274954452436898
# 15.928074733388897
# 9.95379608659434
# 10.030468390012851
#
# standard deviation are as follows
# 7.455206509195465
# 12.725108585802925
# 15.798825196667774
# 15.068548633768618
# 9.652790121115506
# 8.528933273890138
# 7.78704868847135
# 8.397390537361595
#
# Variance are as follows
# 55.645338958711406
# 162.11844531451342
# 249.89583871880217
# 227.32766163473858
# 93.28571904381015
# 72.82808154961408
# 60.70929878751142
# 70.59893329217778

# %%
pxx_den = np.repeat(p0,2)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy

r=numpy.array(10000000*pxx_den[1:1140])
x=numpy.array(abs(f_inst_imf_one[1:1140]))
y=numpy.array(a1[1:1140])

fig = plt.figure(figsize=(7,5))
ax = Axes3D(fig)

#ax = plt.axes(projection='3d')
#ax.contour3D(x, y, r, 50, cmap='binary')
# plot data
line1 = ax.plot(x,y,r,'ok')

#modify axes
#ax.set_xlim(0,6)
#ax.set_ylim(0,8)
ax.minorticks_on()
ax.tick_params(axis='both',which='minor')
ax.tick_params(axis='both',which='major')
ax.set_xlabel('x:Instantaneous Frequency')
ax.set_ylabel('y:Time')
ax.set_zlabel('z:Power_density(10^-7)');
#display 
plt.show()

# %%
dsp_0 = np.fft.fftshift(np.abs(np.fft.fft(IMF[0])) ** 2)
dsp_1 = np.fft.fftshift(np.abs(np.fft.fft(IMF[1])) ** 2)
dsp_2 = np.fft.fftshift(np.abs(np.fft.fft(IMF[2])) ** 2)
dsp_3 = np.fft.fftshift(np.abs(np.fft.fft(IMF[3])) ** 2)
dsp_4 = np.fft.fftshift(np.abs(np.fft.fft(IMF[4])) ** 2)
dsp_5 = np.fft.fftshift(np.abs(np.fft.fft(IMF[5])) ** 2)
dsp_6 = np.fft.fftshift(np.abs(np.fft.fft(IMF[6])) ** 2)


plt.figure(figsize = [20, 20])
#plt.subplot(4, 2, 1)
plt.plot(np.arange(0, 1704, dtype=float), dsp_0)

#plt.subplot(4, 2, 2)
plt.plot(np.arange(0, 1704, dtype=float), dsp_1)

#plt.subplot(4, 2, 3)
plt.plot(np.arange(0, 1704, dtype=float), dsp_2)

#plt.subplot(4, 2, 4)
plt.plot(np.arange(0, 1704, dtype=float), dsp_3)

#plt.subplot(4, 2, 5)
plt.plot(np.arange(0, 1704, dtype=float), dsp_4)

#plt.subplot(4, 2, 6)
plt.plot(np.arange(0, 1704, dtype=float), dsp_5)

#plt.subplot(4, 2, 7)
plt.plot(np.arange(0, 1704, dtype=float), dsp_6)


# plt.xlim(-0.5, 0.5)
# plt.title('Spectrum')
# plt.ylabel('Squared modulus')
# plt.xlabel('Normalized Frequency')
plt.grid()

plt.show()

# %%
import numpy as np
print('\nmean are as follows')
print(np.mean(abs(dsp_0)))
print(np.mean(abs(dsp_1)))
print(np.mean(abs(dsp_2)))
print(np.mean(abs(dsp_3)))
print(np.mean(abs(dsp_4)))
print(np.mean(abs(dsp_5)))
print(np.mean(abs(dsp_6)))
#print(np.mean(abs(dsp_7)))
print('\nstandard deviation are as follows')
print(np.std(dsp_0))
print(np.std(dsp_1))
print(np.std(dsp_2))
print(np.std(dsp_3))
print(np.std(dsp_4))
print(np.std(dsp_5))
print(np.std(dsp_6))
#print(np.std(dsp_7))
print('\nVariance are as follows')
print(statistics.variance(dsp_0))
print(statistics.variance(dsp_1))
print(statistics.variance(dsp_2))
print(statistics.variance(dsp_3))
print(statistics.variance(dsp_4))
print(statistics.variance(dsp_5))
print(statistics.variance(dsp_6))
#print(statistics.variance(dsp_7))

print('\n dominant frequency is 875khz')
# Out:
# mean are as follows
# 1.4315345498144436
# 4.859769475712314
# 7.069482581366485
# 6.620074938387534
# 5.913692678567105
# 12.179039529805115
# 30.604550876601106
#
# standard deviation are as follows
# 2.188700385919667
# 13.3239082970115
# 23.61650175097889
# 35.596149452126554
# 41.91472838209111
# 160.7626575503182
# 424.5116834099727
#
# Variance are as follows
# 4.7932223032117625
# 177.6307757201532
# 558.0666588617717
# 1267.8298874422155
# 1757.8760727580645
# 25859.808006306557
# 180315.98859370136
#
#  dominant frequency is 875khz

# %%
print('Entrophy are as follows')
print('Entrophy for MCF_100')

def entropy4(labels, base=None):
  value,counts = np.unique(labels, return_counts=True)
  norm_counts = counts / counts.sum()
  base = e if base is None else base
  return -(norm_counts * np.log(norm_counts)/np.log(base)).sum()
print(entropy4(IMF[0]))
print(entropy4(IMF[1]))
print(entropy4(IMF[2]))
print(entropy4(IMF[3]))
print(entropy4(IMF[4]))
print(entropy4(IMF[5]))
print(entropy4(IMF[6]))
# Out:
# Entrophy are as follows
# Entrophy for MCF_100
# 7.440733707389259
# 7.440733707389259
# 7.440733707389259
# 7.440733707389259
# 7.440733707389259
# 7.440733707389259
# 7.440733707389259

# %%
print('For Imf[0]')
print('energy during cell growth(blue)')
dsp_g = np.fft.fftshift(np.abs(np.fft.fft(IMF[0][1:420])) ** 2)
plt.plot(np.arange(0, 419, dtype=float), dsp_g,'-b',label='growth')
print('energy during confluenece(yellow)')
dsp_c = np.fft.fftshift(np.abs(np.fft.fft(IMF[0][421:1140])) ** 2)
plt.plot(np.arange(0, 719, dtype=float), dsp_c,'-y',label='conluence')
print('energy during death phase(green)')
dsp_d = np.fft.fftshift(np.abs(np.fft.fft(IMF[0][1142:1700])) ** 2)
plt.plot(np.arange(0, 558, dtype=float), dsp_d,'-g',label='death')
print(np.mean(abs(dsp_g)))
print(np.mean(abs(dsp_c)))
print(np.mean(abs(dsp_d)))
plt.xlabel('frequency', fontsize=12)
plt.ylabel('energy-imf0', fontsize=12)
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF7_imf0.png",dpi=300)
# Out:
# For Imf[0]
# energy during cell growth(blue)
# energy during confluenece(yellow)
# energy during death phase(green)
# 0.2679816471254882
# 0.6834615613157943
# 0.475555550041726

# %%
print('For Imf[1]')
print('energy during cell growth(blue)')
dsp_g = np.fft.fftshift(np.abs(np.fft.fft(IMF[1][1:420])) ** 2)
plt.plot(np.arange(0, 419, dtype=float), dsp_g,'-b',label='growth')
print('energy during confluenece(yellow)')
dsp_c = np.fft.fftshift(np.abs(np.fft.fft(IMF[1][421:1140])) ** 2)
plt.plot(np.arange(0, 719, dtype=float), dsp_c,'-y',label='conluence')
print('energy during death phase(green)')
dsp_d = np.fft.fftshift(np.abs(np.fft.fft(IMF[1][1142:1700])) ** 2)
plt.plot(np.arange(0, 558, dtype=float), dsp_d,'-g',label='death')
print(np.mean(abs(dsp_g)))
print(np.mean(abs(dsp_c)))
print(np.mean(abs(dsp_d)))
plt.xlabel('frequency', fontsize=12)
plt.ylabel('energy-imf1', fontsize=12)
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF7_imf1.png",dpi=300)
# Out:
# For Imf[1]
# energy during cell growth(blue)
# energy during confluenece(yellow)
# energy during death phase(green)
# 1.3352339290073578
# 2.5939324895079956
# 0.9000790778293141

# %%
print('For Imf[2]')
print('energy during cell growth(blue)')
dsp_g = np.fft.fftshift(np.abs(np.fft.fft(IMF[2][1:420])) ** 2)
plt.plot(np.arange(0, 419, dtype=float), dsp_g,'-b',label='growth')
print('energy during confluenece(yellow)')
dsp_c = np.fft.fftshift(np.abs(np.fft.fft(IMF[2][421:1140])) ** 2)
plt.plot(np.arange(0, 719, dtype=float), dsp_c,'-y',label='conluence')
print('energy during death phase(green)')
dsp_d = np.fft.fftshift(np.abs(np.fft.fft(IMF[2][1142:1700])) ** 2)
plt.plot(np.arange(0, 558, dtype=float), dsp_d,'-g',label='death')
print(np.mean(abs(dsp_g)))
print(np.mean(abs(dsp_c)))
print(np.mean(abs(dsp_d)))
plt.xlabel('frequency', fontsize=12)
plt.ylabel('energy-imf2', fontsize=12)
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF7_imf1.png",dpi=300)
# Out:
# For Imf[2]
# energy during cell growth(blue)
# energy during confluenece(yellow)
# energy during death phase(green)
# 1.777936533217585
# 4.15427286267978
# 1.0026677781200448

# %%
print('For Imf[3]')
print('energy during cell growth(blue)')
dsp_g = np.fft.fftshift(np.abs(np.fft.fft(IMF[3][1:420])) ** 2)
plt.plot(np.arange(0, 419, dtype=float), dsp_g,'-b',label='growth')
print('energy during confluenece(yellow)')
dsp_c = np.fft.fftshift(np.abs(np.fft.fft(IMF[3][421:1140])) ** 2)
plt.plot(np.arange(0, 719, dtype=float), dsp_c,'-y',label='conluence')
print('energy during death phase(green)')
dsp_d = np.fft.fftshift(np.abs(np.fft.fft(IMF[3][1142:1700])) ** 2)
plt.plot(np.arange(0, 558, dtype=float), dsp_d,'-g',label='death')
print(np.mean(abs(dsp_g)))
print(np.mean(abs(dsp_c)))
print(np.mean(abs(dsp_d)))
plt.xlabel('frequency', fontsize=12)
plt.ylabel('energy-imf3', fontsize=12)
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF7_imf2.png",dpi=300)
# Out:
# For Imf[3]
# energy during cell growth(blue)
# energy during confluenece(yellow)
# energy during death phase(green)
# 1.0631492274545773
# 4.306117001417191
# 1.2398257298428892

# %%
print('For Imf[4]')
print('energy during cell growth(blue)')
dsp_g = np.fft.fftshift(np.abs(np.fft.fft(IMF[4][1:420])) ** 2)
plt.plot(np.arange(0, 419, dtype=float), dsp_g,'-b',label='growth')
print('energy during confluenece(yellow)')
dsp_c = np.fft.fftshift(np.abs(np.fft.fft(IMF[4][421:1140])) ** 2)
plt.plot(np.arange(0, 719, dtype=float), dsp_c,'-y',label='conluence')
print('energy during death phase(green)')
dsp_d = np.fft.fftshift(np.abs(np.fft.fft(IMF[4][1142:1700])) ** 2)
plt.plot(np.arange(0, 558, dtype=float), dsp_d,'-g',label='death')
print(np.mean(abs(dsp_g)))
print(np.mean(abs(dsp_c)))
print(np.mean(abs(dsp_d)))
plt.xlabel('frequency', fontsize=12)
plt.ylabel('energy-imf4', fontsize=12)
plt.legend(loc='upper left')
plt.show()
plt.savefig("emd_MCF7_imf3.png",dpi=300)
# Out:
# For Imf[4]
# energy during cell growth(blue)
# energy during confluenece(yellow)
# energy during death phase(green)
# 0.8499832456206584
# 2.685501309955225
# 2.238043132713707
